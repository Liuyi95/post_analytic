# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# Import functions for data preprocessing & data preparation
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample
from sklearn.feature_extraction.text import CountVectorizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer, LancasterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords
from nltk.corpus import wordnet
import string
from string import punctuation
import nltk
import re

# %%
df=pd.read_csv('a_haunting_in_venice_result.csv')
df.head()
df=df.drop(['videoId','dislikeCount','favoriteCount'], axis=1)

# %%
df['comments']
# Out:
# 0     ['Good, but well known scary tricks, excellent...
# 1     ['Once you see David Suchet as Poirot, no othe...
# 2     ['I thought there were going to be demons', 'B...
# 3     ['This should&#39;ve been released on Hallowee...
# 4     ['Amazing movie, right in the nostalgia', 'Amo...
# 5     ['More about truth than lies.  What is the who...
# 6     ['Agatha would be spinning in her grave!', 'Wa...
# 7     ['How did you like the ending?', 'the ending t...
# 8     ['I love the assistants characters.', 'Time wa...
# 9     ['Hmmm...Poirot in a horror film. I still don&...
# 10                                          No comments
# 11    ['I would LOVE to see Mystery Inc. solve a mys...
# 12    ['Omggg I have to see thisss', 'Man I hope the...
# 13    ['Just went to this and slept the whole time. ...
# 14    ['Krasser film🔥🔥🔥', 'Erst mega Happy, cool ein...
# 15    ['Looks lame and formulaic', 'Just visited ver...
# 16         ['I&#39;m looking forward to this Movie. 😊']
# 17    ['Great movie ❤❤', 'Looks great, I&#39;d see i...
# 18    ['Blonde girl killed her own daughter she come...
# 19    ['Where is Ken Curtis and royal dano', 'The am...
# 20    ['Verdammt zum Glück auch!!!', 'Der letzte Fil...
# 21    ['Who did tina fey sleep with to get this role...
# 22    ['I really enjoyed the movie but it had nothin...
# 23    ['A haunting in Venice is epic', 'Let me guess...
# 24    ['Where is Ken Curtis and royal dano', 'I like...
# 25    ['Please 👋 someone 🧑🏻👧🏻 connect me with direct...
# 26    ['I watched it in the theatre, before they mov...
# 27    ['Kelly Reilly againg with Poirot... Love it.'...
# 28    ['Fey is horribly flat trying to pull off a Ju...
# 29    ['Omg I’m so sorry for the editing in this vid...
# Name: comments, dtype: object

# %% [markdown]
# Data labelling

# %%
nltk.download('vader_lexicon')
sentiments = SentimentIntensityAnalyzer()
df["Positive"] = [sentiments.polarity_scores(i)["pos"] for i in df["comments"]]
df["Negative"] = [sentiments.polarity_scores(i)["neg"] for i in df["comments"]]
df["Neutral"] = [sentiments.polarity_scores(i)["neu"] for i in df["comments"]]
df['Compound'] = [sentiments.polarity_scores(i)["compound"] for i in df["comments"]]
score = df["Compound"].values
sentiment = []
for i in score:
    if i >= 0.05 :
        sentiment.append('Positive')
    elif i <= -0.05 :
        sentiment.append('Negative')
    else:
        sentiment.append('Neutral')
df["Sentiment"] = sentiment
df.head()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/liuyichen/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#                                                title  viewCount  likeCount  \
# 0  A Haunting In Venice | Official Trailer | In T...    5548272      40461
# 1                A Haunting in Venice - Movie Review     168895       8105
# 2                A Haunting in Venice - Movie Review     194545      11200
# 3  A Haunting In Venice | Teaser Trailer | 20th C...    5465407      47687
# 4  A Haunting In Venice | Haunting Mystery | In T...    3958561       1123
#
#    commentCount         publishedDate  \
# 0          1806  2023-07-19T12:39:34Z
# 1           575  2023-09-12T15:30:06Z
# 2           524  2023-09-15T21:46:08Z
# 3          1488  2023-04-26T17:47:13Z
# 4            67  2023-08-15T16:00:39Z
#
#                                             comments  Positive  Negative  \
# 0  ['Good, but well known scary tricks, excellent...     0.284     0.086
# 1  ['Once you see David Suchet as Poirot, no othe...     0.144     0.170
# 2  ['I thought there were going to be demons', 'B...     0.175     0.115
# 3  ['This should&#39;ve been released on Hallowee...     0.231     0.108
# 4  ['Amazing movie, right in the nostalgia', 'Amo...     0.205     0.060
#
#    Neutral  Compound Sentiment
# 0    0.629    0.9982  Positive
# 1    0.685   -0.9781  Negative
# 2    0.711    0.9860  Positive
# 3    0.662    0.9830  Positive
# 4    0.735    0.9951  Positive
